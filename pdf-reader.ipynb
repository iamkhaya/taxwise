# %%
# Read pdf into DataFrame
import tabula
import pandas as pd

list_of_df = tabula.read_pdf('zimra.pdf', pages="18-20")

columns = []# Read pdf into DataFrame
import tabula
import pandas as pd

list_of_df = tabula.read_pdf('zimra.pdf', pages="18-20")

columns = []

# print(list_of_df)

for idx, df in enumerate(list_of_df):

    
    if isinstance(df, pd.DataFrame):
        print(f"Page number : {idx} has {len(df.columns)} columns")
        # print(df)
        
        columns.append(len(df.columns))
        
        

        if len(df.columns) == 5:
            # Type one page

            df.columns = ['Heading',
                      'Commodity Code',
                      'Description',
                      'Quantity',
                      'General']
        elif len(df.columns) == 6:
            # Type one page
            df.columns = ['Heading',
                      'Commodity Code',
                      'Description',
                      'Quantity',
                      'General',
                    'Other Column']

        elif len(df.columns) == 10:
             # Type 2
            df.columns = [
                'heading',
                'CD',
                'article_description',
                'statistical_unit',
                'general_rate_of_duty',
                'eu_rate_of_duty',
                'efta_rate_of_duty',
                'sadc_rate_of_duty',
                'unknown_1',
                'mercosur_rate_of_duty',
            ]
            
        elif len(df.columns) == 12:
             # Type 3
            df.columns = [
                'heading',
                'CD',
                'article_description',
                'statistical_unit',
                'general_rate_of_duty',
                'eu_rate_of_duty',
                'efta_rate_of_duty',
                'sadc_rate_of_duty',
                'unknown_1',
                'mercosur_rate_of_duty',
                'unknown_2',
                'unknown_3',

            ]
        


        for row in df.iterrows():
            data = row[1]
            # print('********************************************************************************************************')
            # print(data)
            # print('********************************************************************************************************')

            if (data.Heading == 'Heading'):
                print("****** header row ******")
                print(data)
                print('********************************************************************************************************')
                continue
            if data.value_counts().size == 2:
                print("****** sub-heading row ******")
                if data.Heading and data.Heading != 'Heading':
                    print("****** sub-heading row - Heading ******")
                    print(type(data.Heading))
                    print(data.Heading)
        
                    print('********************************************************************************************************')
                continue
            else:
                # print("****** tarriff row ******")
                # print(data)
                # write_tarriff_to_db(data)
                # print('********************************************************************************************************')
                continue
    else:
            print(f"Skipping Page number : {idx}")
            continue



print("unique columns : %s", set(columns))
# Out:
# Page number : 0 has 5 columns
# ****** sub-heading row ******
# ****** sub-heading row - Heading ******
# <class 'str'>
# 02.03
# ********************************************************************************************************
# ****** header row ******
# Heading                        Heading
# Commodity Code               Commodity
# Description       Description of goods
# Quantity                      Quantity
# General                   RATE OF DUTY
# Name: 5, dtype: object
# ********************************************************************************************************
# ****** sub-heading row ******
# ****** sub-heading row - Heading ******
# <class 'str'>
# 02.04
# ********************************************************************************************************
# Page number : 1 has 6 columns
# ****** header row ******
# Heading                        Heading
# Commodity Code               Commodity
# Description       Description of goods
# Quantity                           NaN
# General                       Quantity
# Other Column              RATE OF DUTY
# Name: 1, dtype: object
# ********************************************************************************************************
# ****** sub-heading row ******
# ****** sub-heading row - Heading ******
# <class 'str'>
# 02.06
# ********************************************************************************************************
# Page number : 2 has 6 columns
# ****** sub-heading row ******
# ****** sub-heading row - Heading ******
# <class 'float'>
# nan
# ********************************************************************************************************
# ****** sub-heading row ******
# ****** sub-heading row - Heading ******
# <class 'float'>
# nan
# ********************************************************************************************************
# ****** sub-heading row ******
# ****** sub-heading row - Heading ******
# <class 'float'>
# nan
# ********************************************************************************************************
# ****** sub-heading row ******
# ****** sub-heading row - Heading ******
# <class 'float'>
# nan
# ********************************************************************************************************
# ****** sub-heading row ******
# ****** sub-heading row - Heading ******
# <class 'float'>
# nan
# ********************************************************************************************************
# ****** sub-heading row ******
# ****** sub-heading row - Heading ******
# <class 'float'>
# nan
# ********************************************************************************************************
# ****** sub-heading row ******
# ****** sub-heading row - Heading ******
# <class 'float'>
# nan
# ********************************************************************************************************
# unique columns : %s {5, 6}
